# %%
import pandas as pd 
import numpy as np
import re
from datetime import datetime
import ast

# %%
recipes_df = pd.read_csv('data/recipes60k.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
recipes_df.head(2)
# Out:
#    Unnamed: 0  RecipeId                               Name  AuthorId  \
# 0           0        38  Low-Fat Berry Blue Frozen Dessert      1533
# 1           1        39                            Biryani      1567
#
#   AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 0     Dancer    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1   elly9812    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry",...
#
#                           RecipeIngredientQuantities  \
# 0                            c("4", "1/4", "1", "1")
# 1  c("1", "4", "2", "2", "8", "1/4", "8", "1/2", ...
#
#                                RecipeIngredientParts  AggregatedRating  \
# 0  c("blueberries", "granulated sugar", "vanilla ...               4.5
# 1  c("saffron", "milk", "hot green chili peppers"...               3.0
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          4.0     170.9         2.5                  1.3                 8.0
# 1          1.0    1110.7        58.8                 16.6               372.8
#
#    SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# 0           29.8                 37.1           3.6          30.2
# 1          368.4                 84.4           9.0          20.4
#
#    ProteinContent  RecipeServings RecipeYield  \
# 0             3.2             4.0         NaN
# 1            63.4             6.0         NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...

# %% [markdown]
# ### Columns to Drop

# %%
recipes_df = recipes_df.drop(columns = ['AuthorId',
                                  'AuthorName',
                                  'DatePublished',
                                   'Description',
                                  'Images',
                                       'Unnamed: 0'])

# %%
recipes_df = recipes_df.drop(columns = ['RecipeYield'])

# %% [markdown]
# ### Drop columns with missing values

# %%
recipes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RecipeId                    60000 non-null  int64
#  1   Name                        60000 non-null  object
#  2   CookTime                    48701 non-null  object
#  3   PrepTime                    60000 non-null  object
#  4   TotalTime                   60000 non-null  object
#  5   RecipeCategory              59999 non-null  object
#  6   Keywords                    59428 non-null  object
#  7   RecipeIngredientQuantities  59998 non-null  object
#  8   RecipeIngredientParts       60000 non-null  object
#  9   AggregatedRating            46378 non-null  float64
#  10  ReviewCount                 47037 non-null  float64
#  11  Calories                    60000 non-null  float64
#  12  FatContent                  60000 non-null  float64
#  13  SaturatedFatContent         60000 non-null  float64
#  14  CholesterolContent          60000 non-null  float64
#  15  SodiumContent               60000 non-null  float64
#  16  CarbohydrateContent         60000 non-null  float64
#  17  FiberContent                60000 non-null  float64
#  18  SugarContent                60000 non-null  float64
#  19  ProteinContent              60000 non-null  float64
#  20  RecipeServings              35440 non-null  float64
#  21  RecipeInstructions          60000 non-null  object
# dtypes: float64(12), int64(1), object(9)
# memory usage: 10.1+ MB

# %%
recipe_clean_df = recipes_df.dropna(how='any',axis=0)

# %%
recipe_clean_df = recipe_clean_df.reset_index()

# %%
#recipe_clean_df.to_csv('data/clean_recipes.csv')

# %% [markdown]
# ## Prep Time and Cook Time into floats

# %%
# remove the string character 
recipe_clean_df['CookTime'] = recipe_clean_df['CookTime'].str.replace(r'PT', '')
recipe_clean_df['PrepTime'] = recipe_clean_df['PrepTime'].str.replace(r'PT', '')
recipe_clean_df['TotalTime'] = recipe_clean_df['TotalTime'].str.replace(r'PT', '')

# %%
# Convert to date time
recipe_clean_df['CookTime'] = recipe_clean_df['CookTime'].str.replace(r'M', '')
recipe_clean_df['PrepTime'] = recipe_clean_df['PrepTime'].str.replace(r'M', '')
recipe_clean_df['TotalTime'] = recipe_clean_df['TotalTime'].str.replace(r'M', '')

# %%
# # convert the hours in to minutes for Cooktime column
# for count, value in enumerate(recipe_clean_df['CookTime']):
#     if type(recipe_clean_df['CookTime'][count]) == int:
#         break
#     elif 'H' in recipe_clean_df['CookTime'][count]:
#         recipe_clean_df['CookTime'][count] = (int(recipe_clean_df['CookTime'][0][:-1])) * 60

# %%
# convert the hours in to minutes for PrepTime column
# for count, value in enumerate(recipe_clean_df['PrepTime']):
#     if 'H' in recipe_clean_df['PrepTime'][count]:
#         recipe_clean_df['PrepTime'][count] = (int(recipe_clean_df['PrepTime'][0][:-1])) * 60

# %% [markdown]
# ### Function to convert string time to minutes

# %%
def time_converter(column):
    for count, value in enumerate(recipe_clean_df[f'{column}']):
        if type(value) == str:
            for count2, item in enumerate(value):
                if item == 'H':
                    if value[-1:]  in 'H':
                        recipe_clean_df[f'{column}'][count] = float(recipe_clean_df[f'{column}'][count][:value.index(item)]) * 60
                    else:
                        recipe_clean_df[f'{column}'][count] = float(recipe_clean_df[f'{column}'][count][:value.index(item)]) * 60 + (float(recipe_clean_df[f'{column}'][count][value.index(item)+1:]))
                        
                elif item == 'S':
                    recipe_clean_df[f'{column}'][count] = 0

# %%
time_converter('TotalTime')
time_converter('PrepTime')
time_converter('CookTime')
# Out:
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
recipe_clean_df['TotalTime'].astype(str).astype(float)
recipe_clean_df['PrepTime'].astype(str).astype(float)
recipe_clean_df['CookTime'].astype(str).astype(float)
# Out:
# 0        1440.0
# 1          25.0
# 2           5.0
# 3          20.0
# 4          30.0
#           ...
# 22461       3.0
# 22462      25.0
# 22463       6.0
# 22464      10.0
# 22465      60.0
# Name: CookTime, Length: 22466, dtype: float64

# %%
recipe_clean_df[recipe_clean_df['TotalTime'].apply(lambda x: isinstance(x, float))]
# Out:
#        index  RecipeId                                        Name CookTime  \
# 0          0        38           Low-Fat Berry Blue Frozen Dessert   1440.0
# 1          1        39                                     Biryani       25
# 3          3        41              Carina's Tofu-Vegetable Kebabs       20
# 5          5        43                        Best Blackbottom Pie    120.0
# 7          7        45  Buttermilk Pie With Gingersnap Crumb Crust       50
# ...      ...       ...                                         ...      ...
# 22450  59948     64298                               Salmon Quiche       40
# 22454  59967     64318                  Chocolate Upside-Down Cake       45
# 22455  59968     64319  Decadent Crock Pot Beef Stew With Red Wine       48
# 22457  59976     64327                     Karo 6-Minute Pecan Pie       55
# 22465  59992     64343     Grandma Knorberg's Pork Chops Casserole     60.0
#
#       PrepTime TotalTime   RecipeCategory  \
# 0           45    1485.0  Frozen Desserts
# 1        240.0     265.0   Chicken Breast
# 3       1440.0    1460.0         Soy/Tofu
# 5           20     140.0              Pie
# 7           30      80.0              Pie
# ...        ...       ...              ...
# 22450       20      60.0           Brunch
# 22454       15      60.0          Dessert
# 22455       30      78.0             Stew
# 22457        5      60.0              Pie
# 22465       20      80.0             Pork
#
#                                                 Keywords  \
# 0      c("Dessert", "Low Protein", "Low Cholesterol",...
# 1      c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# 3      c("Beans", "Vegetable", "Low Cholesterol", "We...
# 5      c("Dessert", "Weeknight", "Stove Top", "< 4 Ho...
# 7      c("Dessert", "Healthy", "Weeknight", "Oven", "...
# ...                                                  ...
# 22450                                        "< 60 Mins"
# 22454  c("Coconut", "Fruit", "Nuts", "Potluck", "Swee...
# 22455  c("Steak", "Meat", "Australian", "Winter", "We...
# 22457         c("Dessert", "Fruit", "Nuts", "< 60 Mins")
# 22465  c("Meat", "Canadian", "Weeknight", "Oven", "< ...
#
#                               RecipeIngredientQuantities  \
# 0                                c("4", "1/4", "1", "1")
# 1      c("1", "4", "2", "2", "8", "1/4", "8", "1/2", ...
# 3      c("12", "1", "2", "1", "10", "1", "3", "2", "2...
# 5      c("1 1/4", "1/4", "6", "1/3", "1/4", "1/4", "2...
# 7      c("3/4", "1", "1", "2", "3", "1/4", "1", "1/2"...
# ...                                                  ...
# 22450  c("1", "4", "1/2", "1", "1", "3", "1/2", "3", ...
# 22454  c("1", "3", "1/3", "1 1/3", "1/2", "1/4", "1",...
# 22455  c("1", "2", "1", "2", "2", "3", "2", "1", "3",...
# 22457           c("3", "1", "1", "2", "1", "1 1/2", "1")
# 22465            c("6", "1", "1/2", "1", "1/2", "1", NA)
#
#                                    RecipeIngredientParts  AggregatedRating  \
# 0      c("blueberries", "granulated sugar", "vanilla ...               4.5
# 1      c("saffron", "milk", "hot green chili peppers"...               3.0
# 3      c("extra firm tofu", "eggplant", "zucchini", "...               4.5
# 5      c("graham cracker crumbs", "sugar", "butter", ...               1.0
# 7      c("sugar", "margarine", "egg", "flour", "salt"...               4.0
# ...                                                  ...               ...
# 22450  c("butter", "dill weed", "salmon", "cream-styl...               5.0
# 22454  c("eggs", "water", "margarine", "butter", "wat...               4.0
# 22455  c("stewing beef", "olive oil", "onion", "celer...               4.5
# 22457  c("eggs", "corn syrup", "sugar", "margarine", ...               5.0
# 22465             c("water", "carrot", "celery", "sage")               4.5
#
#        ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0              4.0     170.9         2.5                  1.3
# 1              1.0    1110.7        58.8                 16.6
# 3              2.0     536.1        24.0                  3.8
# 5              1.0     437.9        19.3                 10.9
# 7              3.0     228.0         7.1                  1.7
# ...            ...       ...         ...                  ...
# 22450          4.0     242.4        15.6                  8.0
# 22454          1.0     373.2        22.5                  5.3
# 22455          9.0     677.4        41.9                 15.4
# 22457          4.0     515.0        26.9                  4.2
# 22465          2.0     349.1        21.4                  7.4
#
#        CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                     8.0           29.8                 37.1           3.6
# 1                   372.8          368.4                 84.4           9.0
# 3                     0.0         1558.6                 64.2          17.3
# 5                    94.3          267.6                 58.0           1.8
# 7                    24.5          281.8                 37.5           0.5
# ...                   ...            ...                  ...           ...
# 22450               143.6          397.0                  9.5           0.2
# 22454                39.7          421.7                 41.9           1.8
# 22455               119.1          549.4                 26.0           3.8
# 22457                79.3          177.2                 67.8           2.8
# 22465               112.6          130.5                  3.0           1.0
#
#        SugarContent  ProteinContent  RecipeServings  \
# 0              30.2             3.2             4.0
# 1              20.4            63.4             6.0
# 3              32.1            29.3             2.0
# 5              42.5             7.0             8.0
# 7              24.7             4.2             8.0
# ...             ...             ...             ...
# 22450           1.6            15.9             6.0
# 22454          28.6             4.8            16.0
# 22455           6.7            34.3             6.0
# 22457          36.2             5.7             8.0
# 22465           1.5            34.1             4.0
#
#                                       RecipeInstructions
# 0      c("Toss 2 cups berries with sugar.", "Let stan...
# 1      c("Soak saffron in warm milk for 5 minutes and...
# 3      c("Drain the tofu, carefully squeezing out exc...
# 5      c("Graham Cracker Crust: In small bowl, combin...
# 7      c("Preheat oven to 350°F.", "Make pie crust, u...
# ...                                                  ...
# 22450  c("Crust: Combine top three ingredients and pr...
# 22454  c("Preheat oven to 350°F.", "Melt butter or ma...
# 22455  c("marinate meat in red wine, olive oil, onion...
# 22457  c("In large bowl, stir together first five ing...
# 22465  c("Place pork chops in 9x13 pan.", "Sprinkle w...
#
# [8308 rows x 23 columns]

# %%
# recipe_df_1 = recipe_clean_df.copy()

# %%
# recipe_clean_df.to_csv('./data/recipes141.csv', sep='\t', encoding='utf-8')

# %%
recipes10_df = recipe_clean_df[:10_000]

# %%
# recipes10k.to_csv('./data/recipes10.csv', sep='\t', encoding='utf-8')

# %%
# recipes10_df = pd.read_csv('data/recipes10.csv', error_bad_lines=False, encoding='utf-8')

# %%
# recipes10k.to_csv('./data/recipes10.csv', sep=',', encoding='utf-8')

# %%
recipes10_df = recipes_df[:10_000]
recipes10_df = recipes10_df.loc[~recipes10_df.RecipeIngredientParts.str.contains("character",  na=False)].reset_index()

# %% [markdown]
# ### Change string to a list

# %%
def list_convert(dataframe, column):
    for count, value in enumerate(dataframe[f'{column}']): 
#         if dataframe[f'{column}'].str.contains('char'):
#             dataframe[f'{column}'][count] = "NA"
        
        
        dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('c(', '')
        dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace(')', '')
        dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('0', '')
        dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('(', '')
        dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('\n', '')
#         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('character', '')
        
        dataframe[f'{column}'][count] = ast.literal_eval(str(dataframe[f'{column}'][count]))
    
#         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].split(",")
#         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].spl
#     recipe_clean_df[f'{column}'] = recipe_clean_df[f'{column}'].str.replace('"', '')
    
#     dataframe[f'{column}'] = dataframe[f'{column}'].apply(lambda x: list(dataframe[f'{column}']))

# %%
list_convert(recipes10_df, 'Keywords')
# Out:
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-606-0cbc64b62037> in <module>
# ----> 1 list_convert(recipes10_df, 'Keywords')
#
# <ipython-input-605-0b8b32d06965> in list_convert(dataframe, column)
#       5
#       6
# ----> 7         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('c(', '')
#       8         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace(')', '')
#       9         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('0', '')
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
list_convert(recipes10_df, 'RecipeIngredientQuantities')
# Out:
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-607-8c4b04087e45> in <module>
# ----> 1 list_convert(recipes10_df, 'RecipeIngredientQuantities')
#
# <ipython-input-605-0b8b32d06965> in list_convert(dataframe, column)
#      12 #         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].replace('character', '')
#      13
# ---> 14         dataframe[f'{column}'][count] = ast.literal_eval(str(dataframe[f'{column}'][count]))
#      15
#      16 #         dataframe[f'{column}'][count] = dataframe[f'{column}'][count].split(",")
#
# ~/opt/anaconda3/lib/python3.7/ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# ~/opt/anaconda3/lib/python3.7/ast.py in _convert(node)
#      70             return node.n
#      71         elif isinstance(node, Tuple):
# ---> 72             return tuple(map(_convert, node.elts))
#      73         elif isinstance(node, List):
#      74             return list(map(_convert, node.elts))
#
# ~/opt/anaconda3/lib/python3.7/ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
#      91     return _convert(node_or_string)
#      92
#
# ~/opt/anaconda3/lib/python3.7/ast.py in _convert_signed_num(node)
#      61             else:
#      62                 return - operand
# ---> 63         return _convert_num(node)
#      64     def _convert(node):
#      65         if isinstance(node, Constant):
#
# ~/opt/anaconda3/lib/python3.7/ast.py in _convert_num(node)
#      53         elif isinstance(node, Num):
#      54             return node.n
# ---> 55         raise ValueError('malformed node or string: ' + repr(node))
#      56     def _convert_signed_num(node):
#      57         if isinstance(node, UnaryOp) and isinstance(node.op, (UAdd, USub)):
#
# ValueError: malformed node or string: <_ast.Name object at 0x7fc7e8484c50>

# %%
list_convert(recipes10_df, 'RecipeIngredientParts')
# Out:
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
list_convert(recipes10_df, 'RecipeInstructions')
# Out:
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Traceback (most recent call last):
#
#   File "/Users/SeanMcNamara/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-609-12f340ccf226>", line 1, in <module>
#     list_convert(recipes10_df, 'RecipeInstructions')
#
#   File "<ipython-input-605-0b8b32d06965>", line 14, in list_convert
#     dataframe[f'{column}'][count] = ast.literal_eval(str(dataframe[f'{column}'][count]))
#
#   File "/Users/SeanMcNamara/opt/anaconda3/lib/python3.7/ast.py", line 46, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "/Users/SeanMcNamara/opt/anaconda3/lib/python3.7/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     "Using a sharp knife cut between the rind and the flesh of each watermelon wedge, leave the flesh sitting on the rind Cut throught the flesh to the rind at about 1 1/2" intervals Insert Jicama slices in the melon slits Mix salt& Chili pepper and sparinkle over the wedges Serve with lemon quarters, squeeze over the fruit as you are eating it."
#                                                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
# recipes10_df = recipes10_df.drop(columns = ['Unnamed: 0', 'index', 'Unnamed: 0.1'])

# %%
# recipes10_df.to_csv('./data/recipes10k_df.csv', sep=',', encoding='utf-8')

# %% [markdown]
# #### No cook time over four hours

# %%
recipes10_df
# Out:
#       index  RecipeId                               Name CookTime PrepTime  \
# 0         0        38  Low-Fat Berry Blue Frozen Dessert    PT24H    PT45M
# 1         1        39                            Biryani    PT25M     PT4H
# 2         2        40                      Best Lemonade     PT5M    PT30M
# 3         3        41     Carina's Tofu-Vegetable Kebabs    PT20M    PT24H
# 4         4        42                       Cabbage Soup    PT30M    PT20M
# ...     ...       ...                                ...      ...      ...
# 9967   9995     13170                     Snickerdoodles    PT10M    PT15M
# 9968   9996     13171                        Souper Rice    PT23M     PT5M
# 9969   9997     13172         Italian Spaghetti Frittata    PT20M     PT8M
# 9970   9998     13173        Chicken with Dates and Wine  PT3H15M    PT20M
# 9971   9999     13174                      Honey Cookies    PT15M    PT10M
#
#      TotalTime   RecipeCategory  \
# 0     PT24H45M  Frozen Desserts
# 1      PT4H25M   Chicken Breast
# 2        PT35M        Beverages
# 3     PT24H20M         Soy/Tofu
# 4        PT50M        Vegetable
# ...        ...              ...
# 9967     PT25M          Dessert
# 9968     PT28M             Rice
# 9969     PT28M        Breakfast
# 9970   PT3H35M          Chicken
# 9971     PT25M     Drop Cookies
#
#                                                Keywords  \
# 0     (Dessert, Low Protein, Low Cholesterol, Health...
# 1     (Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2     (Low Protein, Low Cholesterol, Healthy, Summer...
# 3     (Beans, Vegetable, Low Cholesterol, Weeknight,...
# 4     (Low Protein, Vegan, Low Cholesterol, Healthy,...
# ...                                                 ...
# 9967       c("Cookie & Brownie", "Kosher", "< 30 Mins")
# 9968      c("Kosher", "Microwave", "< 30 Mins", "Easy")
# 9969  c("Lunch/Snacks", "Spaghetti", "Cheese", "Euro...
# 9970  c("Poultry", "Meat", "Kosher", "Free Of...", "...
# 9971  c("Dessert", "Cookie & Brownie", "European", "...
#
#                              RecipeIngredientQuantities  \
# 0                                        (4, 1/4, 1, 1)
# 1     "1", "4", "2", "2", "8", "1/4", "8", "1/2", "1...
# 2               c("1 1/2", "1", NA, "1 1/2", NA, "3/4")
# 3     c("12", "1", "2", "1", "10", "1", "3", "2", "2...
# 4                           c("46", "4", "1", "2", "1")
# ...                                                 ...
# 9967  c("1", "1 1/2", "2", "2 3/4", "2", "1", "1/4",...
# 9968                            c("1", "2", "2", "1/4")
# 9969               c("1/2", "1/3", "1/4", "1", "4", NA)
# 9970       c("1", "1", "1/3", "3", "100", "100", "100")
# 9971   c("3", "3/4", "3/4", "3/4", "3 1/2", "1", "1/4")
#
#                                   RecipeIngredientParts  AggregatedRating  \
# 0     (blueberries, granulated sugar, vanilla yogurt...               4.5
# 1     (saffron, milk, hot green chili peppers, onion...               3.0
# 2     (sugar, lemons, rind of, lemon, zest of, fresh...               4.5
# 3     (extra firm tofu, eggplant, zucchini, mushroom...               4.5
# 4     (plain tomato juice, cabbage, onion, carrots, ...               4.5
# ...                                                 ...               ...
# 9967  (margarine, sugar, eggs, self-rising flour, cr...               5.0
# 9968                           (rice, water, margarine)               3.5
# 9969  (spaghetti, parmesan cheese, butter, fresh par...               4.0
# 9970  (chicken, sweet red wine, date honey, honey, d...               5.0
# 9971  (eggs, honey, sugar, flour, baking powder, cin...               3.0
#
#       ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0             4.0     170.9         2.5                  1.3
# 1             1.0    1110.7        58.8                 16.6
# 2            10.0     311.1         0.2                  0.0
# 3             2.0     536.1        24.0                  3.8
# 4            11.0     103.6         0.4                  0.1
# ...           ...       ...         ...                  ...
# 9967         18.0     170.9         7.8                  1.4
# 9968          2.0     138.4         5.8                  1.0
# 9969          1.0     422.9        19.7                 10.4
# 9970          1.0     605.0        33.3                  7.4
# 9971          5.0     153.8         6.1                  0.9
#
#       CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                    8.0           29.8                 37.1           3.6
# 1                  372.8          368.4                 84.4           9.0
# 2                    0.0            1.8                 81.5           0.4
# 3                    0.0         1558.6                 64.2          17.3
# 4                    0.0          959.3                 25.1           4.8
# ...                  ...            ...                  ...           ...
# 9967                16.9          339.1                 23.6           0.5
# 9968                 0.0           67.9                 19.4           0.3
# 9969               249.3          282.4                 43.4           1.9
# 9970               115.0          176.3                 39.0           4.6
# 9971                21.1           19.7                 23.2           0.4
#
#       SugarContent  ProteinContent  RecipeServings  \
# 0             30.2             3.2             4.0
# 1             20.4            63.4             6.0
# 2             77.2             0.3             4.0
# 3             32.1            29.3             2.0
# 4             17.7             4.3             4.0
# ...            ...             ...             ...
# 9967          13.1             1.9             NaN
# 9968           0.0             1.7             8.0
# 9969           1.5            17.1             4.0
# 9970          28.0            34.0             6.0
# 9971          12.0             2.2             NaN
#
#                                      RecipeInstructions
# 0     (Toss 2 cups berries with sugar., Let stand fo...
# 1     (Soak saffron in warm milk for 5 minutes and p...
# 2     (Into a 1 quart Jar with tight fitting lid, pu...
# 3     (Drain the tofu, carefully squeezing out exces...
# 4     (Mix everything together and bring to a boil.,...
# ...                                                 ...
# 9967  c("Mix the cinnamon with the sugar in a bowl a...
# 9968  c("Mix the rice and water in a microwave bowl....
# 9969  c("Drain the spaghetti and stir in the cheese,...
# 9970  c("Preheat the oven to medium-high.", "Clean a...
# 9971  c("Mix all ingredients together.", "Drop spoon...
#
# [9972 rows x 23 columns]

# %%
recipes10_df = recipes10_df[(recipes10_df['CookTime'] <= 240) & (recipes10_df['TotalTime'] <= 480)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-620-5339d5599ee7> in <module>
# ----> 1 recipes10_df = recipes10_df[(recipes10_df['CookTime'] <= 240) & (recipes10_df['TotalTime'] <= 480)]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py in __le__(self, other)
#      42     @unpack_zerodim_and_defer("__le__")
#      43     def __le__(self, other):
# ---> 44         return self._cmp_method(other, operator.le)
#      45
#      46     @unpack_zerodim_and_defer("__gt__")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Check Data is in correct range

# %%
recipes10_df = recipes10_df[(recipes10_df['RecipeServings'] > 0) & (recipes10_df['RecipeServings'] < 20)]

# %% [markdown]
# #### Return recipes where Number of reviews is greater than 2

# %%
recipes10_df = recipes10_df[recipes10_df['ReviewCount'] > 2]

# %% [markdown]
# #### Create calories per serving column

# %%
recipes10_df['calories_per_serving'] = recipes10_df['Calories']/recipes10_df['RecipeServings']

# %%
recipes10_df = recipes10_df[recipes10_df['calories_per_serving'] < 500].reset_index().drop(columns = 'index')
